# %% [markdown]
# ### Face detection using face recognitions library

# %%
import face_recognition as fc
import cv2

# %%
img=fc.load_image_file("test_group.jpg")

# %%
points=fc.face_locations(img)

# %%
import pylab as plt
points
# Out:
# [(2019, 2274, 3169, 1124), (1150, 5516, 2108, 4557)]

# %%
for x,y,w,h in points:
    cv2.rectangle(img,(y,x),(h,w),(0,255,0),5)
plt.imshow(img)

# %% [markdown]
# ### Live video face recognition

# %%
import cv2
import face_recognition

# %%
cap=cv2.VideoCapture(0)  # activating the camara
while True:         # for unlimited time to do process
    ret,frame=cap.read()   # returns the frame and frame number
    points=fc.face_locations(frame)  # used to locate the points
    for x,y,w,h in points:     
        cv2.rectangle(frame,(y,x),(h,w),(0,255,0),5)
    cv2.imshow('detecting faces',frame)   # return the frame after detection
    if cv2.waitKey(1) & 0xff==ord('q'):   # used for closing the loop by typing the "q" from keyboard
        break
cap.release()        # deacitvating the cam which we used now
cv2.destroyAllWindows()   # closing the all related windows which are opened

# %% [markdown]
# ### Face detection using Haar Casecade file

# %%
import cv2
import pylab as plt
facecade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
img=cv2.imread("happy.jpg")  # here cv2 read image in the BGR format
plt.imshow(img)

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces= facecade.detectMultiScale(gray,1.1,4)
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),4)
plt.imshow(img)

# %% [markdown]
# ### Live video code

# %%
import cv2
facecade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
cap=cv2.VideoCapture(0)  # activating the camara
while True:         # for unlimited time to do process
    ret,frame=cap.read()   # returns the frame and frame number
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    faces= facecade.detectMultiScale(gray,1.2,4)
    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
    cv2.imshow('detecting faces',frame)   # return the frame after detection
    if cv2.waitKey(1) & 0xff==ord('q'):   # used for closing the loop by typing the "q" from keyboard
        break
cap.release()        # deacitvating the cam which we used now
cv2.destroyAllWindows()   # closing the all related windows which are opened
